# %%
#Importing the Libraries
import pandas as pd
from pandas import datetime
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
from sklearn.preprocessing import MinMaxScaler
import sklearn as skl

from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.dates as mandates
from sklearn import linear_model
# from keras.models import Sequential
# from keras.layers import Dense
# import keras.backend as K
# from keras.callbacks import EarlyStopping
#from keras.optimizers import Adam
# from keras.models import load_model
# from keras.layers import LSTM
# from keras.utils.vis_utils import plot_model
# Out:
# C:\Users\TNBAUTISTA\AppData\Local\Temp\ipykernel_7688\591871176.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
#Get the Dataset
df=pd.read_csv("NewData/JPM2016_2022.csv",na_values=['null'],index_col='Date',parse_dates=True,infer_datetime_format=True)
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2016-01-04  63.950001  64.059998  63.009998  63.619999  53.557831  25393200
# 2016-01-05  63.700001  64.129997  63.040001  63.730000  53.650433  16566700
# 2016-01-06  62.720001  63.130001  62.340000  62.810001  52.875938  22961500
# 2016-01-07  61.459999  62.000000  60.080002  60.270000  50.737659  27630900
# 2016-01-08  61.130001  61.270000  58.849998  58.919998  49.601185  22373300

# %%
df.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
#Print the shape of Dataframe  and Check for Null Values
print("Dataframe Shape: ", df. shape)
print("Null Value Present: ", df.isnull().values.any())
# Out:
# Dataframe Shape:  (1606, 6)
# Null Value Present:  False

# %%
#Plot the True Adj Close Value
df["Open"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Set Target Variable
output_var = pd.DataFrame(df["Open"])
#Selecting the Features
features = ['Close', 'High', 'Low', 'Volume']

# %%
# Scale the data using MinMax
scaler = MinMaxScaler()
feature_transform = scaler.fit_transform(df[features])
feature_transform= pd.DataFrame(columns=features, data=feature_transform, index=df.index)
feature_transform.head()
# Out:
#                Close      High       Low    Volume
# Date
# 2016-01-04  0.088872  0.085258  0.089038  0.417434
# 2016-01-05  0.089799  0.085846  0.089292  0.250480
# 2016-01-06  0.082049  0.077446  0.083362  0.371438
# 2016-01-07  0.060652  0.067955  0.064216  0.459760
# 2016-01-08  0.049280  0.061823  0.053795  0.360312

# %%
#Splitting to Training set and Test set
timesplit= TimeSeriesSplit(n_splits=10)
for train_index, test_index in timesplit.split(feature_transform):
        X_train, X_test = feature_transform[:len(train_index)], feature_transform[len(train_index): (len(train_index)+len(test_index))]
        y_train, y_test = output_var[:len(train_index)].values.ravel(), output_var[len(train_index): (len(train_index)+len(test_index))].values.ravel()

# %%
#Process the data for LSTM
trainX =np.array(X_train)
testX =np.array(X_test)
X_train = trainX.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = testX.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
from keras.layers import LSTM, Dense, Dropout
from keras.models import Sequential
from keras.layers import Dense
import keras.backend as K
from keras.callbacks import EarlyStopping
# from keras.optimizers import Adam
from keras.models import load_model

from keras.utils.vis_utils import plot_model

# %%
#Building the LSTM Model
lstm = Sequential()
lstm.add(LSTM(32, input_shape=(1, trainX.shape[1]), activation='relu', return_sequences=False))
lstm.add(Dense(1))
lstm.compile(loss='mean_squared_error', optimizer='adam')
plot_model(lstm, show_shapes=True, show_layer_names=True)

# %%
#Model Training
history=lstm.fit(X_train, y_train, epochs=100, batch_size=8, verbose=1, shuffle=False)
# Out:
# Epoch 1/100
# 183/183 [==============================] - 1s 1ms/step - loss: 11693.0420
# Epoch 2/100
# 183/183 [==============================] - 0s 1ms/step - loss: 11096.8896
# Epoch 3/100
# 183/183 [==============================] - 0s 1ms/step - loss: 9914.2676
# Epoch 4/100
# 183/183 [==============================] - 0s 1ms/step - loss: 8292.8164
# Epoch 5/100
# 183/183 [==============================] - 0s 1ms/step - loss: 6509.2930
# Epoch 6/100
# 183/183 [==============================] - 0s 1ms/step - loss: 4790.9331
# Epoch 7/100
# 183/183 [==============================] - 0s 1ms/step - loss: 3290.0474
# Epoch 8/100
# 183/183 [==============================] - 0s 1ms/step - loss: 2091.5994
# Epoch 9/100
# 183/183 [==============================] - 0s 1ms/step - loss: 1220.3651
# Epoch 10/100
# 183/183 [==============================] - 0s 1ms/step - loss: 649.9667
# Epoch 11/100
# 183/183 [==============================] - 0s 1ms/step - loss: 318.3904
# Epoch 12/100
# 183/183 [==============================] - 0s 1ms/step - loss: 149.6721
# Epoch 13/100
# 183/183 [==============================] - 0s 1ms/step - loss: 75.2808
# Epoch 14/100
# 183/183 [==============================] - 0s 1ms/step - loss: 46.8495
# Epoch 15/100
# 183/183 [==============================] - 0s 1ms/step - loss: 37.1742
# Epoch 16/100
100
# 183/183 [==============================] - 0s 1ms/step - loss: 1.5056
# Epoch 61/100
# 183/183 [==============================] - 0s 1ms/step - loss: 1.3926
# Epoch 62/100
# 183/183 [==============================] - 0s 1ms/step - loss: 1.2968
# Epoch 63/100
# 183/183 [==============================] - 0s 1ms/step - loss: 1.2167
# Epoch 64/100
# 183/183 [==============================] - 0s 1ms/step - loss: 1.1504
# Epoch 65/100
# 183/183 [==============================] - 0s 1ms/step - loss: 1.0965
# Epoch 66/100
# 183/183 [==============================] - 0s 1ms/step - loss: 1.0531
# Epoch 67/100
# 183/183 [==============================] - 0s 1ms/step - loss: 1.0187
# Epoch 68/100
# 183/183 [==============================] - 0s 1ms/step - loss: 0.9918
# Epoch 69/100
# 183/183 [==============================] - 0s 1ms/step - loss: 0.9708
# Epoch 70/100
# 183/183 [==============================] - 0s 1ms/step - loss: 0.9546
# Epoch 71/100
# 183/183 [==============================] - 0s 1ms/step - loss: 0.9420
# Epoch 72/100
# 183/183 [==============================] - 0s 1ms/step - loss: 0.9322
# Epoch 73/100
# 183/183 [==============================] - 0s 1ms/step - loss: 0.9243
# Epoch 74/100
# 183/183 [==============================] - 0s 1ms/step - loss: 0.9180
# Epoch 75/100
# 183/183 [==============================] - 0s 1ms/step - loss: 0.9128
# Epoch 76/100
# 183/183 [==============================] - 0s 1ms/step - loss: 0.9084
# Epoch 77/100
# 183/183 [==============================] - 0s 1ms/step - loss: 0.9047
# Epoch 78/100
# 183/183 [==============================] - 0s 1ms/step - loss: 0.9015
# Epoch 79/100
# 183/183 [==============================] - 0s 1ms/step - loss: 0.8986
# Epoch 80/100
# 183/183 [==============================] - 0s 1ms/step - loss: 0.8960
# Epoch 81/100
# 183/183 [==============================] - 0s 1ms/step - loss: 0.8937
# Epoch 82/100
# 183/183 [==============================] - 0s 1ms/step - loss: 0.8915
# Epoch 83/100
# 183/183 [==============================] - 0s 1ms/step - loss: 0.8894
# Epoch 84/100
# 183/183 [==============================] - 0s 1ms/step - loss: 0.8874
# Epoch 85/100
# 183/183 [==============================] - 0s 1ms/step - loss: 0.8855
# Epoch 86/100
# 183/183 [==============================] - 0s 2ms/step - loss: 0.8837
# Epoch 87/100
# 183/183 [==============================] - 0s 2ms/step - loss: 0.8819
# Epoch 88/100
# 183/183 [==============================] - 0s 1ms/step - loss: 0.8801
# Epoch 89/100
# 183/183 [==============================] - 0s 2ms/step - loss: 0.8784
# Epoch 90/100
# 183/183 [==============================] - 0s 2ms/step - loss: 0.8768
# Epoch 91/100
# 183/183 [==============================] - 0s 2ms/step - loss: 0.8751
# Epoch 92/100
# 183/183 [==============================] - 0s 2ms/step - loss: 0.8735
# Epoch 93/100
# 183/183 [==============================] - 0s 2ms/step - loss: 0.8720
# Epoch 94/100
# 183/183 [==============================] - 0s 2ms/step - loss: 0.8704
# Epoch 95/100
# 183/183 [==============================] - 0s 2ms/step - loss: 0.8689
# Epoch 96/100
# 183/183 [==============================] - 0s 2ms/step - loss: 0.8674
# Epoch 97/100
# 183/183 [==============================] - 0s 2ms/step - loss: 0.8660
# Epoch 98/100
# 183/183 [==============================] - 0s 2ms/step - loss: 0.8646
# Epoch 99/100
# 183/183 [==============================] - 0s 2ms/step - loss: 0.8632
# Epoch 100/100
# 183/183 [==============================] - 0s 2ms/step - loss: 0.8619

# %%
lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 32)                4736
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 4,769
# Trainable params: 4,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
#LSTM Prediction
y_pred= lstm.predict(X_test)
y_pred
# Out:
# array([[169.13576 ],
#        [169.3048  ],
#        [170.57161 ],
#        [170.84927 ],
#        [170.89714 ],
#        [168.1122  ],
#        [169.06506 ],
#        [169.97212 ],
#        [169.86098 ],
#        [169.8204  ],
#        [169.70338 ],
#        [167.79686 ],
#        [168.03726 ],
#        [169.1006  ],
#        [167.1389  ],
#        [167.43971 ],
#        [167.30508 ],
#        [166.31891 ],
#        [166.37476 ],
#        [165.4132  ],
#        [164.0486  ],
#        [163.14    ],
#        [160.44786 ],
#        [163.9208  ],
#        [166.8041  ],
#        [167.13142 ],
#        [160.68457 ],
#        [161.56178 ],
#        [158.80235 ],
#        [159.37056 ],
#        [160.67773 ],
#        [158.78978 ],
#        [160.41223 ],
#        [161.9963  ],
#        [161.02992 ],
#        [159.6606  ],
#        [159.90758 ],
#        [158.03833 ],
#        [158.76411 ],
#        [158.05287 ],
#        [159.7942  ],
#        [156.51036 ],
#        [153.22607 ],
#        [155.8797  ],
#        [156.1356  ],
#        [157.66122 ],
#        [157.3493  ],
#        [158.74464 ],
#        [158.56929 ],
#        [158.8174  ],
#        [158.33626 ],
#        [160.85915 ],
#        [166.10838 ],
#        [164.73232 ],
#        [165.04204 ],
#        [165.98943 ],
#        [166.8126  ],
#        [166.88908 ],
#        [167.80785 ],
#        [168.03743 ],
#        [157.6732  ],
#        [152.00978 ],
#        [149.65259 ],
#        [148.44313 ],
#        [145.47955 ],
#        [143.01509 ],
#        [144.51634 ],
#        [147.93465 ],
#        [146.51271 ],
#        [145.0493  ],
#        [147.19412 ],
#        [150.10088 ],
#        [149.51317 ],
#        [149.45787 ],
#        [151.33212 ],
#        [152.30492 ],
#        [156.0066  ],
#        [156.40147 ],
#        [156.41171 ],
#        [154.74924 ],
#        [151.89839 ],
#        [154.65668 ],
#        [154.76237 ],
#        [151.80907 ],
#        [152.31186 ],
#        [151.68614 ],
#        [149.90959 ],
#        [142.85103 ],
#        [147.47768 ],
#        [142.33775 ],
#        [136.60785 ],
#        [138.60248 ],
#        [138.80902 ],
#        [134.10297 ],
#        [130.36299 ],
#        [129.27037 ],
#        [133.79745 ],
#        [131.98875 ],
#        [130.62053 ],
#        [130.91873 ],
#        [132.49445 ],
#        [137.04991 ],
#        [138.69951 ],
#        [139.70726 ],
#        [139.75815 ],
#        [142.75041 ],
#        [140.24663 ],
#        [140.20625 ],
#        [142.01369 ],
#        [139.92181 ],
#        [141.71562 ],
#        [140.92696 ],
#        [137.72118 ],
#        [135.58177 ],
#        [135.27275 ],
#        [134.05322 ],
#        [131.80984 ],
#        [130.6916  ],
#        [133.05286 ],
#        [133.63338 ],
#        [132.42178 ],
#        [127.574905],
#        [126.643745],
#        [127.86773 ],
#        [130.31458 ],
#        [132.29112 ],
#        [131.26753 ],
#        [128.20598 ],
#        [125.775345],
#        [124.31701 ],
#        [122.28204 ],
#        [122.86149 ],
#        [120.85871 ],
#        [119.96247 ],
#        [122.822914],
#        [125.84104 ],
#        [124.23592 ],
#        [123.21213 ],
#        [122.08129 ],
#        [120.30674 ],
#        [119.90391 ],
#        [117.40778 ],
#        [119.272224],
#        [118.48879 ],
#        [122.154564],
#        [120.73243 ]], dtype=float32)

# %%
JPM_Prediction = pd.DataFrame(y_pred)
JPM_Prediction
# Out:
#               0
# 0    169.135757
# 1    169.304794
# 2    170.571609
# 3    170.849274
# 4    170.897141
# ..          ...
# 141  117.407784
# 142  119.272224
# 143  118.488792
# 144  122.154564
# 145  120.732430
#
# [146 rows x 1 columns]

# %%
# write BAC Prediction list to csv
JPM_Prediction.to_csv("Outputs/JPM_Prediction.csv", index=False)

# %%
from jupyterthemes import jtplot

# %%
#Predicted vs True Adj Close Value – LSTM
jtplot.style(theme='grade3',context='notebook',ticks=True,grid=True)
plt.plot(y_test, label='The Actual Prices')
plt.plot(y_pred, label='Predicted Prices')
plt.title("JPM Price Prediction by LSTM")
plt.xlabel('Time Scale')
plt.ylabel('Stock Prices (USD)')
plt.legend()
plt.show()
#plt.savefig("BAC_LSTM_graph")

# %%
from sklearn.metrics import mean_squared_error
import math
from math import sqrt
import requests
import keras
from keras.models import load_model
from sklearn import preprocessing
import sklearn.preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder

# %%
def denormalize(df, normalized_value):
    df = df['Open'].values.reshape(-1,1)
    normalized_value = normalized_value.reshape(-1,1)

    #return df.shape, p.shape
    min_max_scaler = preprocessing.MinMaxScaler()
    a = min_max_scaler.fit_transform(df)
    new = min_max_scaler.inverse_transform(normalized_value)
    return new
p = lstm.predict(X_test)
newp = denormalize(df, p)
newy_test = denormalize(df, y_test)

# %%
# use F score to measure the model

def model_F_score(newp,newy_test):
    TP=0
    FN=0
    FP=0
    for i in range(len(newp)-1):
        test_prof=newy_test[i+1]-newy_test[i]
        p_prof=newp[i+1] - newp[i]

        if((test_prof>=0) and (p_prof>=0)):
            TP=TP+1
        if ((test_prof>= 0) and (p_prof<0)):
            FN=FN+1
        if ((test_prof<0) and (p_prof>=0)):
            FP=FP+1

    Precision=float(TP)/float(TP+FP)
    Recall=float(TP)/float(TP+FN)

    Fscore= 2.0*Precision*Recall/(Precision+Recall)
    print('classification F score: %.5f' % (Fscore))
    return Fscore
    
testScore = math.sqrt(mean_squared_error(newp, newy_test))
print('Test Score: %.2f RMSE' % (testScore))

F_score=model_F_score(newp,newy_test)
print ('F_score',F_score)
# Out:
# Test Score: 161.61 RMSE
# classification F score: 0.74453
# F_score 0.7445255474452556
